# %%
import pandas as pd

# %%
course_df = pd.read_csv(r"C:\Users\mrmik\OneDrive\Desktop\Cycling capstone\Datasets\structured_course_data.csv")

# %%
#course_df = course_df.drop('Unnamed: 0	', axis=1,inplace=True)
course_df
# Out:
#                                  Race Name  Distance  Street   Road  Paved  \
# 0       2022 A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        2022 AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        2022 AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     2022 Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     2022 Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                                    ...       ...     ...    ...    ...
# 8089                 2022 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8090                 2022 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8091                 2022 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8092                 2022 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8093                 2022 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
# ...

# %%
course_df[course_df["Race Name"].str.contains('Paris-Roubaix')]
# Out:
#                        Race Name  Distance  Street   Road  Paved  Asphalt  \
# 1144  2023 Paris-Roubaix Espoirs   161.179   10.30  131.0   17.8    109.0
# 1145   2023 Paris-Roubaix Femmes   145.061    9.89  112.0   11.7    103.0
# 1146          2023 Paris-Roubaix   257.350   14.10  173.0   17.2    185.0
# 4875          2019 Paris-Roubaix   254.820   12.50  172.0   16.1    186.0
# 6897   2021 Paris-Roubaix Femmes   117.000     NaN    NaN    NaN      NaN
# 6898          2021 Paris-Roubaix   257.000     NaN    NaN    NaN      NaN
# 7734   2022 Paris-Roubaix Femmes   123.950    7.97   88.2   10.0     83.6
# 7735          2022 Paris-Roubaix   257.000     NaN    NaN    NaN      NaN
#
#        Path  Cycleway  Unpaved  State Road  ...  Compacted Gravel  \
# 1144  1.820      16.0    2.090        1.08  ...               NaN
# 1145  0.571      15.5    0.927        5.01  ...               NaN
# 1146  4.460      19.4    0.978       45.00  ...               NaN
# ...

# %%
roubaix = course_df.iloc[[1146, 4875,6898,7735]]
roubaix
# Out:
#                Race Name  Distance  Street   Road  Paved  Asphalt  Path  \
# 1146  2023 Paris-Roubaix    257.35    14.1  173.0   17.2    185.0  4.46
# 4875  2019 Paris-Roubaix    254.82    12.5  172.0   16.1    186.0  5.00
# 6898  2021 Paris-Roubaix    257.00     NaN    NaN    NaN      NaN   NaN
# 7735  2022 Paris-Roubaix    257.00     NaN    NaN    NaN      NaN   NaN
#
#       Cycleway  Unpaved  State Road  ...  Compacted Gravel  \
# 1146      19.4    0.978        45.0  ...               NaN
# 4875      18.6    2.470        44.7  ...               NaN
# 6898       NaN      NaN         NaN  ...               NaN
# 7735       NaN      NaN         NaN  ...               NaN
#
#       Off-grid (unknown)  Singletrack  Access Road  Alpine  Net Gain  \
# 1146                1.39        0.465          NaN     NaN     -40.0
# 4875                2.02        1.250          NaN     NaN     -40.0
# 6898                 NaN          NaN          NaN     NaN     -40.0
# ...

# %%
course_df[course_df["Race Name"].str.contains('Dauphine')]
# Out:
#                                 Race Name  Distance  Street    Road   Paved  \
# 643    2023 Criterium du Dauphine Stage 1   158.730   0.418  158.00     NaN
# 644    2023 Criterium du Dauphine Stage 2   167.900     NaN  140.00     NaN
# 645    2023 Criterium du Dauphine Stage 3   194.200   0.660  157.00   4.740
# 646    2023 Criterium du Dauphine Stage 4    31.000     NaN   31.00     NaN
# 647    2023 Criterium du Dauphine Stage 5   190.588   0.188  160.00   1.450
# 648    2023 Criterium du Dauphine Stage 6   171.338   0.208  147.00   2.710
# 649    2023 Criterium du Dauphine Stage 7   148.668   0.324  111.00   0.776
# 650    2023 Criterium du Dauphine Stage 8   152.792   0.193  136.00   1.070
# 1952   2017 Criterium du Dauphine Stage 1   170.000     NaN     NaN     NaN
# 1953   2017 Criterium du Dauphine Stage 2   170.114   0.464  141.00   2.600
# 1954   2017 Criterium du Dauphine Stage 3   185.266     NaN  143.00   1.360
# ...
