# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#code to webscrape PC for race class

#url = "https://www.procyclingstats.com/races.php?year=2024&month=&xnation=&filter=Filter&p=gravel&s=gravel-calendar"

#headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

#response = requests.get(url, headers=headers)
#soup = BeautifulSoup(response.text, "html.parser")

#table = soup.find("table", {"class": "basic"})

#headers = [th.text.strip() for th in table.find_all("th")]

#data = []
#for row in table.find_all("tr")[1:]:
    #cells = row.find_all("td")
    #data.append([cell.text.strip() for cell in cells])

#df = pd.DataFrame(data, columns=headers)
#df.to_excel("uci_gravel_race_classifications_2024.xlsx", index=False)

# %%
core_df = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\data\structured_course_data.xlsx")
core_df
# Out:
#                                  Race Name  Distance  Street   Road  Paved  \
# 0       2022 A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        2022 AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        2022 AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     2022 Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     2022 Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                                    ...       ...     ...    ...    ...
# 8089                 2022 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8090                 2022 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8091                 2022 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8092                 2022 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8093                 2022 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Alpine  Net Gain  \
# 0       106.0   NaN       NaN      NaN         NaN  ...     NaN      50.0
# 1        96.1   NaN       NaN      NaN         NaN  ...     NaN     -20.0
# 2       101.0  2.68     4.030     1.02         NaN  ...     NaN      50.0
# 3       101.0   NaN     0.983      NaN       14.80  ...     NaN      40.0
# 4        98.0   NaN       NaN      NaN        1.96  ...     NaN      20.0
# ...       ...   ...       ...      ...         ...  ...     ...       ...
# 8089     84.0   NaN     9.080      NaN         NaN  ...     NaN       NaN
# 8090      NaN   NaN       NaN      NaN         NaN  ...     NaN       NaN
# 8091      NaN   NaN       NaN      NaN         NaN  ...     NaN       NaN
# 8092      NaN   NaN       NaN      NaN         NaN  ...     NaN      20.0
# 8093      NaN   NaN       NaN      NaN         NaN  ...     NaN      10.0
#
#       Lowest Elevation  Highest Elevation  Vertical Gain  Downhill  Gender  \
# 0                 41.0              144.0          900.0     850.0     Men
# 1                167.0              425.0         1660.0    1680.0     Men
# 2                236.0              447.0         1760.0    1710.0     Men
# 3                208.0              409.0         1110.0    1070.0     Men
# 4                200.0              415.0          950.0     930.0     Men
# ...                ...                ...            ...       ...     ...
# 8089              -1.0               11.0          120.0     120.0     Men
# 8090              -2.0               10.0          210.0     210.0     Men
# 8091              22.0              289.0         1350.0    1350.0     Men
# 8092               6.0               27.0          360.0     340.0     Men
# 8093              -1.0               18.0          260.0     250.0     Men
#
#       Race Level   Race Type  Location
# 0          Other     Unknown    Europe
# 1          Other  Stage Race   Unknown
# 2          Other  Stage Race   Unknown
# 3          Other  Stage Race   Unknown
# 4          Other  Stage Race   Unknown
# ...          ...         ...       ...
# 8089       Other  Stage Race   Unknown
# 8090       Other  Stage Race   Unknown
# 8091       Other  Stage Race   Unknown
# 8092       Other  Stage Race   Unknown
# 8093       Other  Stage Race   Unknown
#
# [8094 rows x 26 columns]

# %%
class_df = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\uci_race_classifications_total.xlsx")
class_df = class_df.rename(columns={'Race': 'Race Name', 'Class': 'Race Level'})
class_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 class_df = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\uci_race_classifications_total.xlsx")
#       2 class_df = class_df.rename(columns={'Race': 'Race Name', 'Class': 'Race Level'})
#       3 class_df
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\mrmik\\OneDrive\\Desktop\\NSS\\Python\\Projects\\Cycling_Capstone\\notebooks\\uci_race_classifications_total.xlsx'

# %%
from thefuzz import process

# %%
def match_race_name(race_name, choices, threshold=90):
    match, score = process.extractOne(race_name, choices)
    return match if score >= threshold else None

# %%
core_df['Matched Race Name'] = core_df['Race Name'].apply(lambda x: match_race_name(x, class_df['Race Name'].tolist()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 core_df['Matched Race Name'] = core_df['Race Name'].apply(lambda x: match_race_name(x, class_df['Race Name'].tolist()))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[7], line 1, in <lambda>(x)
# ----> 1 core_df['Matched Race Name'] = core_df['Race Name'].apply(lambda x: match_race_name(x, class_df['Race Name'].tolist()))
#
# NameError: name 'class_df' is not defined

# %%
merged_df = core_df.merge(class_df, left_on='Matched Race Name', right_on='Race Name', how='left', suffixes=('_old', ''))

# %%
merged_df = merged_df.drop(columns=['Race Name_old', 'Matched Race Name']).rename(columns={'Race Name': 'Race Name', 'Race Level': 'Race Level'})

# %%
merged_df.to_excel('reset_threshold_matched_Race_Name.xlsx')

# %%
core_df = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\core.xlsx")

# %%
core_df
# Out:
#       Unnamed: 0  Distance  Street   Road  Paved  Asphalt  Path  Cycleway  \
# 0              0   117.440    2.44  115.0  11.50    106.0   NaN       NaN
# 1              1   110.560    1.56  109.0  14.40     96.1   NaN       NaN
# 2              2   113.260    5.55  101.0  11.60    101.0  2.68     4.030
# 3              3   104.283     NaN   88.5   3.45    101.0   NaN     0.983
# 4              4    98.060     NaN   96.1    NaN     98.0   NaN       NaN
# ...          ...       ...     ...    ...    ...      ...   ...       ...
# 8834        8834   101.360    8.68   83.6   5.69     84.0   NaN     9.080
# 8835        8835   183.000     NaN    NaN    NaN      NaN   NaN       NaN
# 8836        8836   192.000     NaN    NaN    NaN      NaN   NaN       NaN
# 8837        8837   198.000     NaN    NaN    NaN      NaN   NaN       NaN
# 8838        8838   160.000     NaN    NaN    NaN      NaN   NaN       NaN
#
#       Unpaved  State Road  ...  Highest Elevation  Vertical Gain  Downhill  \
# 0         NaN         NaN  ...              144.0          900.0     850.0
# 1         NaN         NaN  ...              425.0         1660.0    1680.0
# 2        1.02         NaN  ...              447.0         1760.0    1710.0
# 3         NaN       14.80  ...              409.0         1110.0    1070.0
# 4         NaN        1.96  ...              415.0          950.0     930.0
# ...       ...         ...  ...                ...            ...       ...
# 8834      NaN         NaN  ...               11.0          120.0     120.0
# 8835      NaN         NaN  ...               10.0          210.0     210.0
# 8836      NaN         NaN  ...              289.0         1350.0    1350.0
# 8837      NaN         NaN  ...               27.0          360.0     340.0
# 8838      NaN         NaN  ...               18.0          260.0     250.0
#
#       Gender  Race Level_old   Race Type  Location          Dates  \
# 0        Men           Other     Unknown    Europe  17.06 - 20.06
# 1        Men           Other  Stage Race   Unknown  15.09 - 16.09
# 2        Men           Other  Stage Race   Unknown  15.09 - 16.09
# 3        Men           Other  Stage Race   Unknown  12.07 - 16.07
# 4        Men           Other  Stage Race   Unknown  12.07 - 16.07
# ...      ...             ...         ...       ...            ...
# 8834     Men           Other  Stage Race   Unknown  07.06 - 11.06
# 8835     Men           Other  Stage Race   Unknown  07.06 - 11.06
# 8836     Men           Other  Stage Race   Unknown  07.06 - 11.06
# 8837     Men           Other  Stage Race   Unknown  07.06 - 11.06
# 8838     Men           Other  Stage Race   Unknown  07.06 - 11.06
#
#                     Race Name  Race Level
# 0        Tour de Suisse Women       2.WWT
# 1        AG Tour de la Semois         2.2
# 2        AG Tour de la Semois         2.2
# 3     Ain Bugey Valromey Tour         2.1
# 4     Ain Bugey Valromey Tour         2.1
# ...                       ...         ...
# 8834                 ZLM Tour       2.Pro
# 8835                 ZLM Tour       2.Pro
# 8836                 ZLM Tour       2.Pro
# 8837                 ZLM Tour       2.Pro
# 8838                 ZLM Tour       2.Pro
#
# [8839 rows x 29 columns]

# %%
core_df = core_df.drop('Race Level_old', axis=1)

# %%
core_df = core_df.drop('Unnamed: 0', axis=1)

# %%
core_df = core_df[['Race Name', 'Dates', 'Race Type', 'Race Level', 'Gender', 'Distance', 'Street',	'Road',	'Paved','Asphalt', 'Path', 'Cycleway', 'Unpaved', 'State Road',	'Cobblestones',	'Unknown', 'Compacted Gravel', 'Off-grid (unknown)', 'Singletrack',	'Access Road', 'Alpine', 'Net Gain', 'Lowest Elevation', 'Highest Elevation', 'Vertical Gain', 'Downhill'
]]

# %%
core_df
# Out:
#                     Race Name          Dates   Race Type Race Level Gender  \
# 0        Tour de Suisse Women  17.06 - 20.06     Unknown      2.WWT    Men
# 1        AG Tour de la Semois  15.09 - 16.09  Stage Race        2.2    Men
# 2        AG Tour de la Semois  15.09 - 16.09  Stage Race        2.2    Men
# 3     Ain Bugey Valromey Tour  12.07 - 16.07  Stage Race        2.1    Men
# 4     Ain Bugey Valromey Tour  12.07 - 16.07  Stage Race        2.1    Men
# ...                       ...            ...         ...        ...    ...
# 8834                 ZLM Tour  07.06 - 11.06  Stage Race      2.Pro    Men
# 8835                 ZLM Tour  07.06 - 11.06  Stage Race      2.Pro    Men
# 8836                 ZLM Tour  07.06 - 11.06  Stage Race      2.Pro    Men
# 8837                 ZLM Tour  07.06 - 11.06  Stage Race      2.Pro    Men
# 8838                 ZLM Tour  07.06 - 11.06  Stage Race      2.Pro    Men
#
#       Distance  Street   Road  Paved  Asphalt  ...  Compacted Gravel  \
# 0      117.440    2.44  115.0  11.50    106.0  ...               NaN
# 1      110.560    1.56  109.0  14.40     96.1  ...               NaN
# 2      113.260    5.55  101.0  11.60    101.0  ...               NaN
# 3      104.283     NaN   88.5   3.45    101.0  ...               NaN
# 4       98.060     NaN   96.1    NaN     98.0  ...               NaN
# ...        ...     ...    ...    ...      ...  ...               ...
# 8834   101.360    8.68   83.6   5.69     84.0  ...               NaN
# 8835   183.000     NaN    NaN    NaN      NaN  ...               NaN
# 8836   192.000     NaN    NaN    NaN      NaN  ...               NaN
# 8837   198.000     NaN    NaN    NaN      NaN  ...               NaN
# 8838   160.000     NaN    NaN    NaN      NaN  ...               NaN
#
#       Off-grid (unknown)  Singletrack  Access Road  Alpine  Net Gain  \
# 0                    NaN          NaN          NaN     NaN      50.0
# 1                    NaN          NaN          NaN     NaN     -20.0
# 2                    NaN          NaN          NaN     NaN      50.0
# 3                    NaN          NaN          NaN     NaN      40.0
# 4                    NaN          NaN          NaN     NaN      20.0
# ...                  ...          ...          ...     ...       ...
# 8834                 NaN          NaN          NaN     NaN       NaN
# 8835                 NaN          NaN          NaN     NaN       NaN
# 8836                 NaN          NaN          NaN     NaN       NaN
# 8837                 NaN          NaN          NaN     NaN      20.0
# 8838                 NaN          NaN          NaN     NaN      10.0
#
#       Lowest Elevation  Highest Elevation  Vertical Gain  Downhill
# 0                 41.0              144.0          900.0     850.0
# 1                167.0              425.0         1660.0    1680.0
# 2                236.0              447.0         1760.0    1710.0
# 3                208.0              409.0         1110.0    1070.0
# 4                200.0              415.0          950.0     930.0
# ...                ...                ...            ...       ...
# 8834              -1.0               11.0          120.0     120.0
# 8835              -2.0               10.0          210.0     210.0
# 8836              22.0              289.0         1350.0    1350.0
# 8837               6.0               27.0          360.0     340.0
# 8838              -1.0               18.0          260.0     250.0
#
# [8839 rows x 26 columns]

# %%
core_df.to_excel('core.xlsx')

# %%
no_class_df = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\core_dataframe.xlsx")
no_class_df
# Out:
#                                  Race Name  Distance  Street   Road  Paved  \
# 0       2022 A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        2022 AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        2022 AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     2022 Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     2022 Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                                    ...       ...     ...    ...    ...
# 8089                 2022 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8090                 2022 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8091                 2022 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8092                 2022 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8093                 2022 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Alpine  Net Gain  \
# 0       106.0   NaN       NaN      NaN         NaN  ...     NaN      50.0
# 1        96.1   NaN       NaN      NaN         NaN  ...     NaN     -20.0
# 2       101.0  2.68     4.030     1.02         NaN  ...     NaN      50.0
# 3       101.0   NaN     0.983      NaN       14.80  ...     NaN      40.0
# 4        98.0   NaN       NaN      NaN        1.96  ...     NaN      20.0
# ...       ...   ...       ...      ...         ...  ...     ...       ...
# 8089     84.0   NaN     9.080      NaN         NaN  ...     NaN       NaN
# 8090      NaN   NaN       NaN      NaN         NaN  ...     NaN       NaN
# 8091      NaN   NaN       NaN      NaN         NaN  ...     NaN       NaN
# 8092      NaN   NaN       NaN      NaN         NaN  ...     NaN      20.0
# 8093      NaN   NaN       NaN      NaN         NaN  ...     NaN      10.0
#
#       Lowest Elevation  Highest Elevation  Vertical Gain  Downhill  Gender  \
# 0                 41.0              144.0          900.0     850.0     Men
# 1                167.0              425.0         1660.0    1680.0     Men
# 2                236.0              447.0         1760.0    1710.0     Men
# 3                208.0              409.0         1110.0    1070.0     Men
# 4                200.0              415.0          950.0     930.0     Men
# ...                ...                ...            ...       ...     ...
# 8089              -1.0               11.0          120.0     120.0     Men
# 8090              -2.0               10.0          210.0     210.0     Men
# 8091              22.0              289.0         1350.0    1350.0     Men
# 8092               6.0               27.0          360.0     340.0     Men
# 8093              -1.0               18.0          260.0     250.0     Men
#
#          Race Level   Race Type  Location
# 0     UCI ProSeries     Unknown    Europe
# 1     UCI ProSeries  Stage Race   Unknown
# 2     UCI ProSeries  Stage Race   Unknown
# 3     UCI ProSeries  Stage Race   Unknown
# 4     UCI ProSeries  Stage Race   Unknown
# ...             ...         ...       ...
# 8089  UCI ProSeries  Stage Race   Unknown
# 8090  UCI ProSeries  Stage Race   Unknown
# 8091  UCI ProSeries  Stage Race   Unknown
# 8092  UCI ProSeries  Stage Race   Unknown
# 8093  UCI ProSeries  Stage Race   Unknown
#
# [8094 rows x 26 columns]

# %%
no_class_df['Year'] = no_class_df['Race Name'].str.extract(r'(\d{4})')

# %%
no_class_df
# Out:
#                                  Race Name  Distance  Street   Road  Paved  \
# 0       2022 A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        2022 AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        2022 AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     2022 Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     2022 Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                                    ...       ...     ...    ...    ...
# 8089                 2022 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8090                 2022 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8091                 2022 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8092                 2022 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8093                 2022 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Net Gain  \
# 0       106.0   NaN       NaN      NaN         NaN  ...      50.0
# 1        96.1   NaN       NaN      NaN         NaN  ...     -20.0
# 2       101.0  2.68     4.030     1.02         NaN  ...      50.0
# 3       101.0   NaN     0.983      NaN       14.80  ...      40.0
# 4        98.0   NaN       NaN      NaN        1.96  ...      20.0
# ...       ...   ...       ...      ...         ...  ...       ...
# 8089     84.0   NaN     9.080      NaN         NaN  ...       NaN
# 8090      NaN   NaN       NaN      NaN         NaN  ...       NaN
# 8091      NaN   NaN       NaN      NaN         NaN  ...       NaN
# 8092      NaN   NaN       NaN      NaN         NaN  ...      20.0
# 8093      NaN   NaN       NaN      NaN         NaN  ...      10.0
#
#       Lowest Elevation  Highest Elevation  Vertical Gain  Downhill  Gender  \
# 0                 41.0              144.0          900.0     850.0     Men
# 1                167.0              425.0         1660.0    1680.0     Men
# 2                236.0              447.0         1760.0    1710.0     Men
# 3                208.0              409.0         1110.0    1070.0     Men
# 4                200.0              415.0          950.0     930.0     Men
# ...                ...                ...            ...       ...     ...
# 8089              -1.0               11.0          120.0     120.0     Men
# 8090              -2.0               10.0          210.0     210.0     Men
# 8091              22.0              289.0         1350.0    1350.0     Men
# 8092               6.0               27.0          360.0     340.0     Men
# 8093              -1.0               18.0          260.0     250.0     Men
#
#          Race Level   Race Type  Location  Year
# 0     UCI ProSeries     Unknown    Europe  2022
# 1     UCI ProSeries  Stage Race   Unknown  2022
# 2     UCI ProSeries  Stage Race   Unknown  2022
# 3     UCI ProSeries  Stage Race   Unknown  2022
# 4     UCI ProSeries  Stage Race   Unknown  2022
# ...             ...         ...       ...   ...
# 8089  UCI ProSeries  Stage Race   Unknown  2022
# 8090  UCI ProSeries  Stage Race   Unknown  2022
# 8091  UCI ProSeries  Stage Race   Unknown  2022
# 8092  UCI ProSeries  Stage Race   Unknown  2022
# 8093  UCI ProSeries  Stage Race   Unknown  2022
#
# [8094 rows x 27 columns]

# %%
no_class_df['Year'].unique()
# Out:
# array(['2022', '2023', '2017', '2018', '2019', '2020', '2021'],
#       dtype=object)

# %%
no_class_df['Race Name'] = no_class_df['Race Name'].str.replace(r'\d{4}', '', regex=True).str.strip()

# %%
no_class_df
# Out:
#                             Race Name  Distance  Street   Road  Paved  \
# 0       A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                               ...       ...     ...    ...    ...
# 8089                 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8090                 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8091                 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8092                 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8093                 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Net Gain  \
# 0       106.0   NaN       NaN      NaN         NaN  ...      50.0
# 1        96.1   NaN       NaN      NaN         NaN  ...     -20.0
# 2       101.0  2.68     4.030     1.02         NaN  ...      50.0
# 3       101.0   NaN     0.983      NaN       14.80  ...      40.0
# 4        98.0   NaN       NaN      NaN        1.96  ...      20.0
# ...       ...   ...       ...      ...         ...  ...       ...
# 8089     84.0   NaN     9.080      NaN         NaN  ...       NaN
# 8090      NaN   NaN       NaN      NaN         NaN  ...       NaN
# 8091      NaN   NaN       NaN      NaN         NaN  ...       NaN
# 8092      NaN   NaN       NaN      NaN         NaN  ...      20.0
# 8093      NaN   NaN       NaN      NaN         NaN  ...      10.0
#
#       Lowest Elevation  Highest Elevation  Vertical Gain  Downhill  Gender  \
# 0                 41.0              144.0          900.0     850.0     Men
# 1                167.0              425.0         1660.0    1680.0     Men
# 2                236.0              447.0         1760.0    1710.0     Men
# 3                208.0              409.0         1110.0    1070.0     Men
# 4                200.0              415.0          950.0     930.0     Men
# ...                ...                ...            ...       ...     ...
# 8089              -1.0               11.0          120.0     120.0     Men
# 8090              -2.0               10.0          210.0     210.0     Men
# 8091              22.0              289.0         1350.0    1350.0     Men
# 8092               6.0               27.0          360.0     340.0     Men
# 8093              -1.0               18.0          260.0     250.0     Men
#
#          Race Level   Race Type  Location  Year
# 0     UCI ProSeries     Unknown    Europe  2022
# 1     UCI ProSeries  Stage Race   Unknown  2022
# 2     UCI ProSeries  Stage Race   Unknown  2022
# 3     UCI ProSeries  Stage Race   Unknown  2022
# 4     UCI ProSeries  Stage Race   Unknown  2022
# ...             ...         ...       ...   ...
# 8089  UCI ProSeries  Stage Race   Unknown  2022
# 8090  UCI ProSeries  Stage Race   Unknown  2022
# 8091  UCI ProSeries  Stage Race   Unknown  2022
# 8092  UCI ProSeries  Stage Race   Unknown  2022
# 8093  UCI ProSeries  Stage Race   Unknown  2022
#
# [8094 rows x 27 columns]

# %%
no_class_df['Race Level'] = ''

# %%
import json
with open(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\race_dict.json", "r") as f:
    race_dict = json.load(f)

# %%
no_class_df['Race Level'] = no_class_df['Race Name'].map(race_dict)

# %%
no_class_df
# Out:
#                             Race Name  Distance  Street   Road  Paved  \
# 0       A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                               ...       ...     ...    ...    ...
# 8089                 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8090                 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8091                 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8092                 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8093                 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Net Gain  \
# 0       106.0   NaN       NaN      NaN         NaN  ...      50.0
# 1        96.1   NaN       NaN      NaN         NaN  ...     -20.0
# 2       101.0  2.68     4.030     1.02         NaN  ...      50.0
# 3       101.0   NaN     0.983      NaN       14.80  ...      40.0
# 4        98.0   NaN       NaN      NaN        1.96  ...      20.0
# ...       ...   ...       ...      ...         ...  ...       ...
# 8089     84.0   NaN     9.080      NaN         NaN  ...       NaN
# 8090      NaN   NaN       NaN      NaN         NaN  ...       NaN
# 8091      NaN   NaN       NaN      NaN         NaN  ...       NaN
# 8092      NaN   NaN       NaN      NaN         NaN  ...      20.0
# 8093      NaN   NaN       NaN      NaN         NaN  ...      10.0
#
#       Lowest Elevation  Highest Elevation  Vertical Gain  Downhill  Gender  \
# 0                 41.0              144.0          900.0     850.0     Men
# 1                167.0              425.0         1660.0    1680.0     Men
# 2                236.0              447.0         1760.0    1710.0     Men
# 3                208.0              409.0         1110.0    1070.0     Men
# 4                200.0              415.0          950.0     930.0     Men
# ...                ...                ...            ...       ...     ...
# 8089              -1.0               11.0          120.0     120.0     Men
# 8090              -2.0               10.0          210.0     210.0     Men
# 8091              22.0              289.0         1350.0    1350.0     Men
# 8092               6.0               27.0          360.0     340.0     Men
# 8093              -1.0               18.0          260.0     250.0     Men
#
#       Race Level   Race Type  Location  Year
# 0            NaN     Unknown    Europe  2022
# 1            NaN  Stage Race   Unknown  2022
# 2            NaN  Stage Race   Unknown  2022
# 3            NaN  Stage Race   Unknown  2022
# 4            NaN  Stage Race   Unknown  2022
# ...          ...         ...       ...   ...
# 8089         NaN  Stage Race   Unknown  2022
# 8090         NaN  Stage Race   Unknown  2022
# 8091         NaN  Stage Race   Unknown  2022
# 8092         NaN  Stage Race   Unknown  2022
# 8093         NaN  Stage Race   Unknown  2022
#
# [8094 rows x 27 columns]

# %%
no_class_df['Race Level'].unique()
# Out:
# array([nan], dtype=object)

# %%
no_class_df['Race Level'].describe()
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# Name: Race Level, dtype: object

# %%
no_class_df['Matched Race Name'] = no_class_df['Race Name'].apply(lambda x: match_race_name(x, list(race_dict.keys())))

# %%
no_class_df['Race Level'] = no_class_df['Matched Race Name'].map(race_dict)

# %%
no_class_df
# Out:
#                             Race Name  Distance  Street   Road  Paved  \
# 0       A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                               ...       ...     ...    ...    ...
# 8089                 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8090                 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8091                 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8092                 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8093                 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Lowest Elevation  \
# 0       106.0   NaN       NaN      NaN         NaN  ...              41.0
# 1        96.1   NaN       NaN      NaN         NaN  ...             167.0
# 2       101.0  2.68     4.030     1.02         NaN  ...             236.0
# 3       101.0   NaN     0.983      NaN       14.80  ...             208.0
# 4        98.0   NaN       NaN      NaN        1.96  ...             200.0
# ...       ...   ...       ...      ...         ...  ...               ...
# 8089     84.0   NaN     9.080      NaN         NaN  ...              -1.0
# 8090      NaN   NaN       NaN      NaN         NaN  ...              -2.0
# 8091      NaN   NaN       NaN      NaN         NaN  ...              22.0
# 8092      NaN   NaN       NaN      NaN         NaN  ...               6.0
# 8093      NaN   NaN       NaN      NaN         NaN  ...              -1.0
#
#       Highest Elevation  Vertical Gain  Downhill  Gender  Race Level  \
# 0                 144.0          900.0     850.0     Men         NaN
# 1                 425.0         1660.0    1680.0     Men         NaN
# 2                 447.0         1760.0    1710.0     Men         NaN
# 3                 409.0         1110.0    1070.0     Men         NaN
# 4                 415.0          950.0     930.0     Men         NaN
# ...                 ...            ...       ...     ...         ...
# 8089               11.0          120.0     120.0     Men         NaN
# 8090               10.0          210.0     210.0     Men         NaN
# 8091              289.0         1350.0    1350.0     Men         NaN
# 8092               27.0          360.0     340.0     Men         NaN
# 8093               18.0          260.0     250.0     Men         NaN
#
#        Race Type  Location  Year  Matched Race Name
# 0        Unknown    Europe  2022               None
# 1     Stage Race   Unknown  2022               None
# 2     Stage Race   Unknown  2022               None
# 3     Stage Race   Unknown  2022               None
# 4     Stage Race   Unknown  2022               None
# ...          ...       ...   ...                ...
# 8089  Stage Race   Unknown  2022               None
# 8090  Stage Race   Unknown  2022               None
# 8091  Stage Race   Unknown  2022               None
# 8092  Stage Race   Unknown  2022               None
# 8093  Stage Race   Unknown  2022               None
#
# [8094 rows x 28 columns]

# %%
no_class_df['Race Name'] = no_class_df['Matched Race Name'].fillna(no_class_df['Race Name'])

# %%
no_class_df['Race Level'].unique()
# Out:
# array(['UCI ProSeries', '2022 Aubel-Thimister-Stavelot Stage 1',
#        '2022 Aubel-Thimister-Stavelot Stage 2-1', ...,
#        '2022 XXVIII. Gipuzkoa Klasikoa Stage 1',
#        '2022 XXVIII. Gipuzkoa Klasikoa Stage 2',
#        '2022 Youngster Coast Challenge'], dtype=object)

# %%
class_df
# Out:
#      Dates                               Race Name Race Level
# 0    05.08      World Championships MJ - Road Race         WC
# 1    05.08      World Championships WJ - Road Race         WC
# 2    06.08      World Championships ME - Road Race         WC
# 3    08.08   World Championships - Mixed Relay TTT         WC
# 4    09.08            World Championships MU - ITT         WC
# ..     ...                                     ...        ...
# 745  15.08  Tour of Leuven - Memorial Jef Scherens        1.1
# 746  18.08                          Konvert Koerse        1.1
# 747  19.08             GP Oetingen by St Feuillien        1.1
# 748  19.08                 Druivenkoers - Overijse        1.1
# 749  20.08                     Egmont Cycling Race        1.1
#
# [750 rows x 3 columns]

# %%
no_class_df['Matched Race Name'] = no_class_df['Race Name'].apply(lambda x: match_race_name(x, class_df['Race Name'].tolist()))
no_class_df = no_class_df.merge(class_df, left_on='Matched Race Name', right_on='Race Name', how='left', suffixes=('_old', ''))
no_class_df['Race Name'] = no_class_df['Matched Race Name'].fillna(no_class_df['Race Name'])
no_class_df['Race Level'] = no_class_df['Race Level'].fillna(no_class_df['Race Level_old'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 no_class_df['Matched Race Name'] = no_class_df['Race Name'].apply(lambda x: match_race_name(x, class_df['Race Name'].tolist()))
#       2 no_class_df = no_class_df.merge(class_df, left_on='Matched Race Name', right_on='Race Name', how='left', suffixes=('_old', ''))
#       3 no_class_df['Race Name'] = no_class_df['Matched Race Name'].fillna(no_class_df['Race Name'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[93], line 1, in <lambda>(x)
# ----> 1 no_class_df['Matched Race Name'] = no_class_df['Race Name'].apply(lambda x: match_race_name(x, class_df['Race Name'].tolist()))
#       2 no_class_df = no_class_df.merge(class_df, left_on='Matched Race Name', right_on='Race Name', how='left', suffixes=('_old', ''))
#       3 no_class_df['Race Name'] = no_class_df['Matched Race Name'].fillna(no_class_df['Race Name'])
#
# Cell In[61], line 2, in match_race_name(race_name, choices, threshold)
#       1 def match_race_name(race_name, choices, threshold=80):
# ----> 2     match, score = process.extractOne(race_name, choices)
#       3     return match if score >= threshold else None
#
# File ~\anaconda3\Lib\site-packages\thefuzz\process.py:260, in extractOne(query, choices, processor, scorer, score_cutoff)
#     257 is_mapping = hasattr(choices, "items")
#     258 is_lowered = scorer in _scorer_lowering
# --> 260 query = _preprocess_query(query, processor)
#     261 res = rprocess.extractOne(
#     262     query, choices,
#     263     processor=_get_processor(processor, scorer),
#     264     scorer=_get_scorer(scorer),
#     265     score_cutoff=score_cutoff
#     266 )
#     268 if res is None:
#
# File ~\anaconda3\Lib\site-packages\thefuzz\process.py:71, in _preprocess_query(query, processor)
#      70 def _preprocess_query(query, processor):
# ---> 71     processed_query = processor(query) if processor else query
#      72     if len(processed_query) == 0:
#      73         _logger.warning("Applied processor reduces input query to empty string, "
#      74                         "all comparisons will have score 0. "
#      75                         f"[Query: \'{query}\']")
#
# File ~\anaconda3\Lib\site-packages\thefuzz\utils.py:22, in full_process(s, force_ascii)
#      19 if force_ascii:
#      20     s = ascii_only(str(s))
# ---> 22 return _default_process(s)
#
# File src/rapidfuzz/utils_cpp.pyx:24, in rapidfuzz.utils_cpp.default_process()
#
# TypeError: sentence must be a String

# %%
no_class_df = no_class_df.drop(columns=['Race Level_old', 'Matched Race Name'])

# %%
no_class_df = no_class_df.rename(columns={'Race Name_old':'Race Name'})

# %%
no_class_df
# Out:
#                             Race Name  Distance  Street   Road  Paved  \
# 0       A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                               ...       ...     ...    ...    ...
# 8466                 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8467                 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8468                 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8469                 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8470                 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Highest Elevation  \
# 0       106.0   NaN       NaN      NaN         NaN  ...              144.0
# 1        96.1   NaN       NaN      NaN         NaN  ...              425.0
# 2       101.0  2.68     4.030     1.02         NaN  ...              447.0
# 3       101.0   NaN     0.983      NaN       14.80  ...              409.0
# 4        98.0   NaN       NaN      NaN        1.96  ...              415.0
# ...       ...   ...       ...      ...         ...  ...                ...
# 8466     84.0   NaN     9.080      NaN         NaN  ...               11.0
# 8467      NaN   NaN       NaN      NaN         NaN  ...               10.0
# 8468      NaN   NaN       NaN      NaN         NaN  ...              289.0
# 8469      NaN   NaN       NaN      NaN         NaN  ...               27.0
# 8470      NaN   NaN       NaN      NaN         NaN  ...               18.0
#
#       Vertical Gain  Downhill  Gender   Race Type  Location  Year  \
# 0             900.0     850.0     Men     Unknown    Europe  2022
# 1            1660.0    1680.0     Men  Stage Race   Unknown  2022
# 2            1760.0    1710.0     Men  Stage Race   Unknown  2022
# 3            1110.0    1070.0     Men  Stage Race   Unknown  2022
# 4             950.0     930.0     Men  Stage Race   Unknown  2022
# ...             ...       ...     ...         ...       ...   ...
# 8466          120.0     120.0     Men  Stage Race   Unknown  2022
# 8467          210.0     210.0     Men  Stage Race   Unknown  2022
# 8468         1350.0    1350.0     Men  Stage Race   Unknown  2022
# 8469          360.0     340.0     Men  Stage Race   Unknown  2022
# 8470          260.0     250.0     Men  Stage Race   Unknown  2022
#
#               Dates                Race Name  Race Level
# 0     25.04 - 30.04         Tour de Romandie       2.UWT
# 1     15.09 - 16.09     AG Tour de la Semois         2.2
# 2     15.09 - 16.09     AG Tour de la Semois         2.2
# 3     12.07 - 16.07  Ain Bugey Valromey Tour         2.1
# 4     12.07 - 16.07  Ain Bugey Valromey Tour         2.1
# ...             ...                      ...         ...
# 8466  07.06 - 11.06                 ZLM Tour       2.Pro
# 8467  07.06 - 11.06                 ZLM Tour       2.Pro
# 8468  07.06 - 11.06                 ZLM Tour       2.Pro
# 8469  07.06 - 11.06                 ZLM Tour       2.Pro
# 8470  07.06 - 11.06                 ZLM Tour       2.Pro
#
# [8471 rows x 29 columns]

# %%
no_class_df.to_excel(r'no_class_df.xlsx')

# %%
no_class_df
# Out:
#                             Race Name  Distance  Street   Road  Paved  \
# 0       A Travers les Hauts de France   117.440    2.44  115.0  11.50
# 1        AG Tour de la Semois Stage 1   110.560    1.56  109.0  14.40
# 2        AG Tour de la Semois Stage 2   113.260    5.55  101.0  11.60
# 3     Ain Bugey Valromey Tour Stage 1   104.283     NaN   88.5   3.45
# 4     Ain Bugey Valromey Tour Stage 2    98.060     NaN   96.1    NaN
# ...                               ...       ...     ...    ...    ...
# 8466                 ZLM Tour Stage 1   101.360    8.68   83.6   5.69
# 8467                 ZLM Tour Stage 2   183.000     NaN    NaN    NaN
# 8468                 ZLM Tour Stage 3   192.000     NaN    NaN    NaN
# 8469                 ZLM Tour Stage 4   198.000     NaN    NaN    NaN
# 8470                 ZLM Tour Stage 5   160.000     NaN    NaN    NaN
#
#       Asphalt  Path  Cycleway  Unpaved  State Road  ...  Highest Elevation  \
# 0       106.0   NaN       NaN      NaN         NaN  ...              144.0
# 1        96.1   NaN       NaN      NaN         NaN  ...              425.0
# 2       101.0  2.68     4.030     1.02         NaN  ...              447.0
# 3       101.0   NaN     0.983      NaN       14.80  ...              409.0
# 4        98.0   NaN       NaN      NaN        1.96  ...              415.0
# ...       ...   ...       ...      ...         ...  ...                ...
# 8466     84.0   NaN     9.080      NaN         NaN  ...               11.0
# 8467      NaN   NaN       NaN      NaN         NaN  ...               10.0
# 8468      NaN   NaN       NaN      NaN         NaN  ...              289.0
# 8469      NaN   NaN       NaN      NaN         NaN  ...               27.0
# 8470      NaN   NaN       NaN      NaN         NaN  ...               18.0
#
#       Vertical Gain  Downhill  Gender   Race Type  Location  Year  \
# 0             900.0     850.0     Men     Unknown    Europe  2022
# 1            1660.0    1680.0     Men  Stage Race   Unknown  2022
# 2            1760.0    1710.0     Men  Stage Race   Unknown  2022
# 3            1110.0    1070.0     Men  Stage Race   Unknown  2022
# 4             950.0     930.0     Men  Stage Race   Unknown  2022
# ...             ...       ...     ...         ...       ...   ...
# 8466          120.0     120.0     Men  Stage Race   Unknown  2022
# 8467          210.0     210.0     Men  Stage Race   Unknown  2022
# 8468         1350.0    1350.0     Men  Stage Race   Unknown  2022
# 8469          360.0     340.0     Men  Stage Race   Unknown  2022
# 8470          260.0     250.0     Men  Stage Race   Unknown  2022
#
#               Dates                Race Name  Race Level
# 0     25.04 - 30.04         Tour de Romandie       2.UWT
# 1     15.09 - 16.09     AG Tour de la Semois         2.2
# 2     15.09 - 16.09     AG Tour de la Semois         2.2
# 3     12.07 - 16.07  Ain Bugey Valromey Tour         2.1
# 4     12.07 - 16.07  Ain Bugey Valromey Tour         2.1
# ...             ...                      ...         ...
# 8466  07.06 - 11.06                 ZLM Tour       2.Pro
# 8467  07.06 - 11.06                 ZLM Tour       2.Pro
# 8468  07.06 - 11.06                 ZLM Tour       2.Pro
# 8469  07.06 - 11.06                 ZLM Tour       2.Pro
# 8470  07.06 - 11.06                 ZLM Tour       2.Pro
#
# [8471 rows x 29 columns]
