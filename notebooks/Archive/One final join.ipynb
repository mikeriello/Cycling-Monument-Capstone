# %%
import pandas as pd

# %%
terrain = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\terrain_data.xlsx")

# %%
terrain['PCS race entry'] = terrain['PCS race entry'].str.lower().str.replace(" ","")

# %%
terrain
# Out:
#          PCS race entry         Race Name          Race Tags    Year  \
# 0    2017amstelgoldrace  Amstel Gold Race  Spring, Adrennes   2017.0
# 1    2018amstelgoldrace  Amstel Gold Race  Spring, Adrennes   2018.0
# 2    2019amstelgoldrace  Amstel Gold Race  Spring, Adrennes   2019.0
# 3    2021amstelgoldrace  Amstel Gold Race  Spring, Adrennes   2021.0
# 4    2022amstelgoldrace  Amstel Gold Race  Spring, Adrennes   2022.0
# ..                  ...               ...                ...     ...
# 97    2020stradebianche    Strade Bianche             Spring  2020.0
# 98    2021stradebianche    Strade Bianche             Spring  2021.0
# 99    2022stradebianche    Strade Bianche             Spring  2022.0
# 100   2023stradebianche    Strade Bianche             Spring  2023.0
# 101                 NaN               NaN                NaN     NaN
#
#      Distance  Street   Road  Paved  Asphalt  Path  ...  Singletrack  \
# ...

# %%
terrain.to_excel('terrain2.xlsx')

# %%
terrain2 = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\terrain2.xlsx")

# %%
terrain2
# Out:
#      Unnamed: 0      PCS race entry         Race Name          Race Tags  \
# 0             0  2017amstelgoldrace  Amstel Gold Race  Spring, Adrennes
# 1             1  2018amstelgoldrace  Amstel Gold Race  Spring, Adrennes
# 2             2  2019amstelgoldrace  Amstel Gold Race  Spring, Adrennes
# 3             3  2021amstelgoldrace  Amstel Gold Race  Spring, Adrennes
# 4             4  2022amstelgoldrace  Amstel Gold Race  Spring, Adrennes
# ..          ...                 ...               ...                ...
# 97           97   2020stradebianche    Strade Bianche             Spring
# 98           98   2021stradebianche    Strade Bianche             Spring
# 99           99   2022stradebianche    Strade Bianche             Spring
# 100         100   2023stradebianche    Strade Bianche             Spring
# 101         101                 NaN               NaN                NaN
#
#        Year  Distance  Street   Road  Paved  Asphalt  ...  Singletrack  \
# ...

# %%
baseline = pd.read_excel(r"C:\Users\mrmik\OneDrive\Desktop\NSS\Python\Projects\Cycling_Capstone\notebooks\baseline_data.xlsx")

# %%
baseline
# Out:
#                 PCS race entry              Race Name  Year  \
# 0           2017amstelgoldrace       Amstel Gold Race  2017
# 1           2018amstelgoldrace       Amstel Gold Race  2018
# 2           2019amstelgoldrace       Amstel Gold Race  2019
# 3           2021amstelgoldrace       Amstel Gold Race  2021
# 4           2022amstelgoldrace       Amstel Gold Race  2022
# ..                         ...                    ...   ...
# 96   2019kuurne-brussel-kuurne  Kuurne-Brussel-Kuurne  2019
# 97   2020kuurne-brussel-kuurne  Kuurne-Brussel-Kuurne  2020
# 98   2021kuurne-brussel-kuurne  Kuurne-Brussel-Kuurne  2021
# 99   2022kuurne-brussel-kuurne  Kuurne-Brussel-Kuurne  2022
# 100  2023kuurne-brussel-kuurne  Kuurne-Brussel-Kuurne  2023
#
#                    Winner  One_day_races specialty points  \
# 0        GILBERT Philippe                           12530
# 1         VALGREN Michael                            2867
# 2    VAN DER POEL Mathieu                            6991
# ...

# %%
final_merge = pd.merge(terrain2, baseline, on='PCS race entry', how='left')

# %%
final_merge.to_excel('left_final.xlsx')
